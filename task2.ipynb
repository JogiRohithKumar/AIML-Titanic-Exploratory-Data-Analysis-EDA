# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("titanic_cleaned.csv")

# %%
print(df.describe(include='all'))
# Out:
#         PassengerId    Survived     Pclass                 Name         Sex  \
# count    775.000000  775.000000  775.00000                  775  775.000000
# unique          NaN         NaN        NaN                  775         NaN
# top             NaN         NaN        NaN  Dooley, Mr. Patrick         NaN
# freq            NaN         NaN        NaN                    1         NaN
# mean     445.806452    0.339355    2.48000                  NaN    0.314839
# std      260.116285    0.473796    0.73439                  NaN    0.464752
# min        1.000000    0.000000    1.00000                  NaN    0.000000
# 25%      213.500000    0.000000    2.00000                  NaN    0.000000
# 50%      450.000000    0.000000    3.00000                  NaN    0.000000
# 75%      670.500000    1.000000    3.00000                  NaN    1.000000
# max      891.000000    1.000000    3.00000                  NaN    1.000000
#
#                  Age       SibSp       Parch  Ticket          Fare Embarked_Q  \
# count   7.750000e+02  775.000000  775.000000     775  7.750000e+02        775
# unique           NaN         NaN         NaN     632           NaN          2
# top              NaN         NaN         NaN  347082           NaN      False
# freq             NaN         NaN         NaN       7           NaN        700
# mean   -8.251464e-17    0.437419    0.340645     NaN  6.876220e-17        NaN
# std     1.000646e+00    0.899838    0.785914     NaN  1.000646e+00        NaN
# min    -2.217707e+00    0.000000    0.000000     NaN -1.313411e+00        NaN
# 25%    -5.283213e-01    0.000000    0.000000     NaN -7.315244e-01        NaN
# 50%    -5.861258e-02    0.000000    0.000000     NaN -3.553671e-01        NaN
# 75%     4.110961e-01    1.000000    0.000000     NaN  6.026763e-01        NaN
# max     4.012196e+00    5.000000    6.000000     NaN  3.476807e+00        NaN
#
#        Embarked_S
# count         775
# unique          2
# top          True
# freq          584
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  775 non-null    int64
#  1   Survived     775 non-null    int64
#  2   Pclass       775 non-null    int64
#  3   Name         775 non-null    object
#  4   Sex          775 non-null    int64
#  5   Age          775 non-null    float64
#  6   SibSp        775 non-null    int64
#  7   Parch        775 non-null    int64
#  8   Ticket       775 non-null    object
#  9   Fare         775 non-null    float64
#  10  Embarked_Q   775 non-null    bool
#  11  Embarked_S   775 non-null    bool
# dtypes: bool(2), float64(2), int64(6), object(2)
# memory usage: 62.2+ KB
# None

# %%
print(df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
df.hist(figsize=(12, 8), color='skyblue', edgecolor='black')
plt.suptitle("Histograms of Numeric Features")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['Age'])
plt.title("Boxplot of Age")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['Fare'])
plt.title("Boxplot of Fare")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
sns.pairplot(df[['Survived', 'Age', 'Fare', 'Pclass', 'SibSp', 'Parch']], hue='Survived')
plt.suptitle("Pairplot of Features", y=1.02)
plt.show()

# %%
fig = px.scatter(df, x='Age', y='Fare', color='Survived', hover_data=['Name'])
fig.show()
